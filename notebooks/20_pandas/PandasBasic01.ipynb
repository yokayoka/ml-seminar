# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
# 環境によっては失敗することもあるので、CSVファイルを読み込んでも構いません。
# タブ区切りを指定します。
# path はご自分の環境に合わせて設定してください
path_NFL_rank = "/content/drive/MyDrive/IPU_Share/deeplearning/NFL_rank.csv"
nfl_frame = pd.read_csv(path_NFL_rank, sep='\t')

# %%
nfl_frame.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North

# %%
# 列（カラム）の名前が.columnsでわかります。

nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
# 列を取り出します

nfl_frame["Team"]
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2           Baltimore Ravens
# 3       New England Patriots
# 4              Chicago Bears
# 5             Miami Dolphins
# 6          Minnesota Vikings
# 7         Kansas City Chiefs
# 8     San Francisco 49ers[b]
# 9        Pittsburgh Steelers
# 10           New York Giants
# 11     Indianapolis Colts[c]
# 12            Denver Broncos
# 13         Las Vegas Raiders
# 14          Seattle Seahawks
# 15          Los Angeles Rams
# 16      Los Angeles Chargers
# 17     Washington Commanders
# 18       Philadelphia Eagles
# 19          Tennessee Titans
# 20    Cleveland Browns[b][d]
# 21             Buffalo Bills
# 22         Carolina Panthers
# 23        New Orleans Saints
# 24        Cincinnati Bengals
# 25             Detroit Lions
# 26             New York Jets
# 27           Atlanta Falcons
# 28            Houston Texans
# 29         Arizona Cardinals
# 30      Jacksonville Jaguars
# 31      Tampa Bay Buccaneers
# ...

# %%
# オブジェクトの属性のような書き方も可能
nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2           Baltimore Ravens
# 3       New England Patriots
# 4              Chicago Bears
# 5             Miami Dolphins
# 6          Minnesota Vikings
# 7         Kansas City Chiefs
# 8     San Francisco 49ers[b]
# 9        Pittsburgh Steelers
# 10           New York Giants
# 11     Indianapolis Colts[c]
# 12            Denver Broncos
# 13         Las Vegas Raiders
# 14          Seattle Seahawks
# 15          Los Angeles Rams
# 16      Los Angeles Chargers
# 17     Washington Commanders
# 18       Philadelphia Eagles
# 19          Tennessee Titans
# 20    Cleveland Browns[b][d]
# 21             Buffalo Bills
# 22         Carolina Panthers
# 23        New Orleans Saints
# 24        Cincinnati Bengals
# 25             Detroit Lions
# 26             New York Jets
# 27           Atlanta Falcons
# 28            Houston Texans
# 29         Arizona Cardinals
# 30      Jacksonville Jaguars
# 31      Tampa Bay Buccaneers
# ...

# %%
# こちらの書き方の方が推奨されていますが、おいおい慣れて行けばOKです。

nfl_frame.loc[:, "Team"]
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2           Baltimore Ravens
# 3       New England Patriots
# 4              Chicago Bears
# 5             Miami Dolphins
# 6          Minnesota Vikings
# 7         Kansas City Chiefs
# 8     San Francisco 49ers[b]
# 9        Pittsburgh Steelers
# 10           New York Giants
# 11     Indianapolis Colts[c]
# 12            Denver Broncos
# 13         Las Vegas Raiders
# 14          Seattle Seahawks
# 15          Los Angeles Rams
# 16      Los Angeles Chargers
# 17     Washington Commanders
# 18       Philadelphia Eagles
# 19          Tennessee Titans
# 20    Cleveland Browns[b][d]
# 21             Buffalo Bills
# 22         Carolina Panthers
# 23        New Orleans Saints
# 24        Cincinnati Bengals
# 25             Detroit Lions
# 26             New York Jets
# 27           Atlanta Falcons
# 28            Houston Texans
# 29         Arizona Cardinals
# 30      Jacksonville Jaguars
# 31      Tampa Bay Buccaneers
# ...

# %%
# 特定のカラムで新しいDataFrameを作る

DataFrame(nfl_frame, columns=["Team", "GP"])
# Out:
#                       Team     GP
# 0           Dallas Cowboys    964
# 1        Green Bay Packers  1,418
# 2         Baltimore Ravens    434
# 3     New England Patriots    966
# 4            Chicago Bears  1,452
# 5           Miami Dolphins    882
# 6        Minnesota Vikings    952
# 7       Kansas City Chiefs    966
# 8   San Francisco 49ers[b]  1,084
# 9      Pittsburgh Steelers  1,254
# 10         New York Giants  1,387
# 11   Indianapolis Colts[c]  1,048
# 12          Denver Broncos    966
# 13       Las Vegas Raiders    966
# 14        Seattle Seahawks    742
# 15        Los Angeles Rams  1,217
# 16    Los Angeles Chargers    966
# 17   Washington Commanders  1,284
# 18     Philadelphia Eagles  1,270
# 19        Tennessee Titans    966
# 20  Cleveland Browns[b][d]  1,036
# 21           Buffalo Bills    965
# 22       Carolina Panthers    450
# 23      New Orleans Saints    868
# 24      Cincinnati Bengals    853
# 25           Detroit Lions  1,315
# ...

# %%
# 先頭だけを表示

nfl_frame.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North

# %%
# 最後だけを表示

nfl_frame.tail(3)
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 29    30     Arizona Cardinals  1,412  581   790    41  0.426
# 30    31  Jacksonville Jaguars    450  189   261     0  0.420
# 31    32  Tampa Bay Buccaneers    742  299   442     1  0.404
#
#     First NFL season   Division
# 29              1920   NFC West
# 30              1995  AFC South
# 31              1976  NFC South

# %%
# 4行目（index=3）の行を取り出す

nfl_frame.iloc[3]
# Out:
# Rank                                   4
# Team                New England Patriots
# GP                                   966
# Won                                  537
# Lost                                 420
# Tied                                   9
# Pct.                               0.561
# First NFL season                    1960
# Division                        AFC East
# Name: 3, dtype: object

# %%
# 列全体に値を代入

nfl_frame["Stadium"] = "Levi's Stadium"  # 文字列内に「'」があるので、全体は「”」で囲む

# %%
nfl_frame
# Out:
#     Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0      1          Dallas Cowboys    964  550   408     6  0.574
# 1      2       Green Bay Packers  1,418  790   590    38  0.571
# 2      3        Baltimore Ravens    434  243   190     1  0.561
# 3      4    New England Patriots    966  537   420     9  0.561
# 4      5           Chicago Bears  1,452  786   624    42  0.556
# 5      6          Miami Dolphins    882  485   393     4  0.552
# 6      7       Minnesota Vikings    952  516   425    11  0.548
# 7      8      Kansas City Chiefs    966  521   433    12  0.546
# 8      9  San Francisco 49ers[b]  1,084  574   496    14  0.536
# 9     10     Pittsburgh Steelers  1,254  661   571    22  0.536
# 10    11         New York Giants  1,387  715   638    34  0.528
# 11    12   Indianapolis Colts[c]  1,048  547   493     8  0.526
# 12    13          Denver Broncos    966  500   456    10  0.523
# 13    14       Las Vegas Raiders    966  497   458    11  0.520
# ...

# %%
nfl_frame["Stadium"] = np.arange(32)
nfl_frame
# Out:
#     Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0      1          Dallas Cowboys    964  550   408     6  0.574
# 1      2       Green Bay Packers  1,418  790   590    38  0.571
# 2      3        Baltimore Ravens    434  243   190     1  0.561
# 3      4    New England Patriots    966  537   420     9  0.561
# 4      5           Chicago Bears  1,452  786   624    42  0.556
# 5      6          Miami Dolphins    882  485   393     4  0.552
# 6      7       Minnesota Vikings    952  516   425    11  0.548
# 7      8      Kansas City Chiefs    966  521   433    12  0.546
# 8      9  San Francisco 49ers[b]  1,084  574   496    14  0.536
# 9     10     Pittsburgh Steelers  1,254  661   571    22  0.536
# 10    11         New York Giants  1,387  715   638    34  0.528
# 11    12   Indianapolis Colts[c]  1,048  547   493     8  0.526
# 12    13          Denver Broncos    966  500   456    10  0.523
# 13    14       Las Vegas Raiders    966  497   458    11  0.520
# ...

# %%
# SeriesをDataFrameに追加する

stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4, 0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame["Stadium"] = stadiums
nfl_frame
# Out:
#     Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0      1          Dallas Cowboys    964  550   408     6  0.574
# 1      2       Green Bay Packers  1,418  790   590    38  0.571
# 2      3        Baltimore Ravens    434  243   190     1  0.561
# 3      4    New England Patriots    966  537   420     9  0.561
# 4      5           Chicago Bears  1,452  786   624    42  0.556
# 5      6          Miami Dolphins    882  485   393     4  0.552
# 6      7       Minnesota Vikings    952  516   425    11  0.548
# 7      8      Kansas City Chiefs    966  521   433    12  0.546
# 8      9  San Francisco 49ers[b]  1,084  574   496    14  0.536
# 9     10     Pittsburgh Steelers  1,254  661   571    22  0.536
# 10    11         New York Giants  1,387  715   638    34  0.528
# 11    12   Indianapolis Colts[c]  1,048  547   493     8  0.526
# 12    13          Denver Broncos    966  500   456    10  0.523
# 13    14       Las Vegas Raiders    966  497   458    11  0.520
# ...

# %%
# 列を消すことも可能

del nfl_frame["Stadium"]
nfl_frame
# Out:
#     Rank                    Team     GP  Won  Lost  Tied   Pct.  \
# 0      1          Dallas Cowboys    964  550   408     6  0.574
# 1      2       Green Bay Packers  1,418  790   590    38  0.571
# 2      3        Baltimore Ravens    434  243   190     1  0.561
# 3      4    New England Patriots    966  537   420     9  0.561
# 4      5           Chicago Bears  1,452  786   624    42  0.556
# 5      6          Miami Dolphins    882  485   393     4  0.552
# 6      7       Minnesota Vikings    952  516   425    11  0.548
# 7      8      Kansas City Chiefs    966  521   433    12  0.546
# 8      9  San Francisco 49ers[b]  1,084  574   496    14  0.536
# 9     10     Pittsburgh Steelers  1,254  661   571    22  0.536
# 10    11         New York Giants  1,387  715   638    34  0.528
# 11    12   Indianapolis Colts[c]  1,048  547   493     8  0.526
# 12    13          Denver Broncos    966  500   456    10  0.523
# 13    14       Las Vegas Raiders    966  497   458    11  0.520
# ...
